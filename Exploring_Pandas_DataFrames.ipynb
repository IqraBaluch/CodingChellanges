# %% [markdown]
# # Pandas DataFrames

# %% [markdown]
# # Import pandas using the alias pd.

# %%
import pandas as pd

# %%
#get dataset in atbular form

mall = pd.read_csv('Desktop/shopping_mall.csv')
print(mall)
# Out:
#       RowNumber  CustomerId         Surname  CreditScore Geography  Gender  \
# 0             1    15634602        Hargrave          619    France  Female
# 1             2    15647311            Hill          608     Spain  Female
# 2             3    15619304            Onio          502    France  Female
# 3             4    15701354            Boni          699    France  Female
# 4             5    15737888        Mitchell          850     Spain  Female
# 5             6    15574012             Chu          645     Spain    Male
# 6             7    15592531        Bartlett          822    France    Male
# 7             8    15656148          Obinna          376   Germany  Female
# 8             9    15792365              He          501    France    Male
# 9            10    15592389              H?          684    France    Male
# 10           11    15767821          Bearce          528    France    Male
# ...

# %% [markdown]
# # Inspecting a DataFrame
# When you get a new DataFrame to work with, the first thing you need to do is explore it and see what it contains. There are several useful methods and attributes for this.
#
# .head() returns the first few rows (the “head” of the DataFrame).<br>
# .info() shows information on each of the columns, such as the data type and number of missing values.<br>
# .shape returns the number of rows and columns of the DataFrame.<br>
# .describe() calculates a few summary statistics for each column.

# %% [markdown]
# # Print the head of dataset

# %%
print(mall.head())
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %% [markdown]
# # Print information about the column types and missing values

# %%
print(mall.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
# RowNumber          10000 non-null int64
# CustomerId         10000 non-null int64
# Surname            10000 non-null object
# CreditScore        10000 non-null int64
# Geography          10000 non-null object
# Gender             10000 non-null object
# Age                10000 non-null int64
# Tenure             10000 non-null int64
# Balance            10000 non-null float64
# NumOfProducts      10000 non-null int64
# HasCrCard          10000 non-null int64
# IsActiveMember     10000 non-null int64
# EstimatedSalary    10000 non-null float64
# Exited             10000 non-null int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB
# None

# %% [markdown]
# # Print the number of rows and columns

# %%
print(mall.shape)
# Out:
# (10000, 14)

# %% [markdown]
# # Print some summary statistics that describe the DataFrame.

# %%
print(mall.describe())
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %% [markdown]
# ***

# %% [markdown]
# # Parts of a DataFrame
# To better understand DataFrame objects, it's useful to know that they consist of three components, stored as attributes: <br>
#
# .values: A two-dimensional NumPy array of values.<br>
# .columns: An index of columns: the column names.<br>
# .index: An index for the rows: either row numbers or row names.

# %% [markdown]
# # Print a 2D NumPy array of the values in dataset

# %%
print([[mall.values]])
# Out:
# [[array([[1, 15634602, 'Hargrave', ..., 1, 101348.88, 1],
#        [2, 15647311, 'Hill', ..., 1, 112542.58, 0],
#        [3, 15619304, 'Onio', ..., 0, 113931.57, 1],
#        ...,
#        [9998, 15584532, 'Liu', ..., 1, 42085.58, 1],
#        [9999, 15682355, 'Sabbatini', ..., 0, 92888.52, 1],
#        [10000, 15628319, 'Walker', ..., 0, 38190.78, 0]], dtype=object)]]

# %% [markdown]
# # Print the column names

# %%
print(mall.columns)
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %% [markdown]
# # Print the index

# %%
print(mall.index)
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %% [markdown]
# ***

# %% [markdown]
# # Sorting rows
# Finding interesting bits of data in a DataFrame is often easier if you change the order of the rows. You can sort the rows by passing a column name to .sort_values().

# %% [markdown]
# # Sort shopping mall's data set by  (EstimatedSalary), from smallest to largest, and save this as "sort_mall"

# %%
sort_mall = mall.sort_values("EstimatedSalary")

# %% [markdown]
# # Print the head of the sorted DataFrame.

# %%
print(sort_mall.head())
# Out:
#       RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 2362       2363    15791053  Lucciano          709   Germany    Male   45
# 9647       9648    15679693    Walker          625    France    Male   31
# 9010       9011    15786463     Hsing          645   Germany  Female   59
# 5548       5549    15639662  Phillips          710    France    Male   38
# 4989       4990    15602851    Ozioma          629    France    Male   40
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 2362       4  122917.71              1          1               1
# 9647       5       0.00              2          0               1
# 9010       8  121669.93              2          0               0
# 5548       2       0.00              2          1               0
# 4989       9       0.00              1          1               0
#
#       EstimatedSalary  Exited
# 2362            11.58       1
# 9647            90.07       0
# ...

# %% [markdown]
# # Sort dataset by the amount of Balance  in descending order, and save this as balance.

# %%
balance = mall.sort_values('Balance' , ascending =False)

# %% [markdown]
# # print the dataframe

# %%
print(balance.head())
# Out:
#       RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 2092       2093    15757408        Lo          655     Spain    Male   38
# 3280       3281    15715622    To Rot          583    France  Female   57
# 8733       8734    15714241    Haddon          749     Spain    Male   42
# 3588       3589    15571958  McIntosh          489     Spain    Male   40
# 6717       6718    15586674      Shaw          663     Spain  Female   58
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 2092       3  250898.09              3          0               1
# 3280       3  238387.56              1          0               1
# 8733       9  222267.63              1          0               0
# 3588       3  221532.80              1          1               0
# 6717       5  216109.88              1          0               1
#
#       EstimatedSalary  Exited
# 2092         81054.00       1
# 3280        147964.99       1
# ...

# %% [markdown]
# # Sort mall first by Age (ascending), and then by number of products (descending).

# %%
ageAndProduct = mall.sort_values(['Age', 'Exited'], ascending = [True, True])

# %% [markdown]
# # Print the head of the sorted DataFrame.

# %%
print(ageAndProduct.head())
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 746         747    15787619      Hsieh          844    France    Male   18
# 1619       1620    15770309   McDonald          656    France    Male   18
# 1678       1679    15569178  Kharlamov          570    France  Female   18
# 2021       2022    15795519   Vasiliev          716   Germany  Female   18
# 2136       2137    15621893   Bellucci          727    France    Male   18
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 746        2  160980.03              1          0               0
# 1619      10  151762.74              1          0               1
# 1678       4   82767.42              1          1               0
# 2021       3  128743.80              1          0               0
# 2136       4  133550.67              1          1               1
#
#       EstimatedSalary  Exited
# 746         145936.28       0
# 1619        127014.32       0
# ...

# %% [markdown]
# ***

# %% [markdown]
# # Subsetting columns
# When working with data, you may not need all of the variables in your dataset. Square brackets ([]) can be used to select only the columns that matter to you in an order that makes sense to you. To select only "col_a" of the DataFrame df, use
# <br>
# df["col_a"]

# %% [markdown]
# # Create a DataFrame called surname that contains only the Surname column
# ## Print the head of the result.

# %%
surname = mall["Surname"]
print(surname)
# Out:
# 0             Hargrave
# 1                 Hill
# 2                 Onio
# 3                 Boni
# 4             Mitchell
# 5                  Chu
# 6             Bartlett
# 7               Obinna
# 8                   He
# 9                   H?
# 10              Bearce
# 11             Andrews
# 12                 Kay
# 13                Chin
# 14               Scott
# 15             Goforth
# 16               Romeo
# 17           Henderson
# 18             Muldrow
# 19                 Hao
# 20            McDonald
# 21            Dellucci
# 22           Gerasimov
# 23              Mosman
# 24                 Yen
# 25             Maclean
# 26               Young
# 27             Nebechi
# 28          McWilliams
# 29            Lucciano
#              ...
# 9970          Thompson
# 9971              Chou
# 9972             Ch'in
# 9973            Miller
# 9974            Barker
# 9975             Smith
# 9976           Azikiwe
# 9977           Mancini
# 9978             P'eng
# ...

# %%
print(surname.head())
# Out:
# 0    Hargrave
# 1        Hill
# 2        Onio
# 3        Boni
# 4    Mitchell
# Name: Surname, dtype: object

# %% [markdown]
# # Create a DataFrame called geograpy_gender that contains only the Geography and Gender columns , in that order.
# # Print the head of the result.

# %%
geography_gender = mall[['Surname', 'Gender']]
                         
print(geography_gender.head(20))
# Out:
#       Surname  Gender
# 0    Hargrave  Female
# 1        Hill  Female
# 2        Onio  Female
# 3        Boni  Female
# 4    Mitchell  Female
# 5         Chu    Male
# 6    Bartlett    Male
# 7      Obinna  Female
# 8          He    Male
# 9          H?    Male
# 10     Bearce    Male
# 11    Andrews    Male
# 12        Kay  Female
# 13       Chin  Female
# 14      Scott  Female
# 15    Goforth    Male
# 16      Romeo    Male
# 17  Henderson  Female
# 18    Muldrow    Male
# 19        Hao  Female

# %% [markdown]
# ***

# %% [markdown]
# # Subsetting rows
# A large part of data science is about finding which bits of your dataset are interesting. One of the simplest techniques for this is to find a subset of rows that match some criteria. This is sometimes known as filtering rows or selecting rows.

# %% [markdown]
# # Filter dataset for cases where EstimatedSalary is greater than ten thousand, assigning to ind_gt_10k. View the printed result.

# %%
salary = mall[mall['EstimatedSalary'] > 156346]
print(salary.head(30))
# Out:
#      RowNumber  CustomerId        Surname  CreditScore Geography  Gender  Age  \
# 13          14    15691483           Chin          549    France  Female   25
# 18          19    15661507        Muldrow          587     Spain    Male   45
# 20          21    15577657       McDonald          732    France    Male   41
# 24          25    15625047            Yen          846    France  Female   38
# 26          27    15736816          Young          756   Germany    Male   36
# 31          32    15706552  Odinakachukwu          533    France    Male   36
# 39          40    15585768        Cameron          582   Germany    Male   41
# 41          42    15738148         Clarke          465    France  Female   51
# 43          44    15755196         Lavine          834    France  Female   49
# 44          45    15684171        Bianchi          660     Spain  Female   61
# 49          50    15771873         Buccho          776   Germany  Female   37
# ...

# %%
# Gender == Male

male = mall[mall["Gender"] == 'Male']
print(male.head())
# Out:
#     RowNumber  CustomerId   Surname  CreditScore Geography Gender  Age  \
# 5           6    15574012       Chu          645     Spain   Male   44
# 6           7    15592531  Bartlett          822    France   Male   50
# 8           9    15792365        He          501    France   Male   44
# 9          10    15592389        H?          684    France   Male   27
# 10         11    15767821    Bearce          528    France   Male   31
#
#     Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 5        8  113755.78              2          1               0
# 6        7       0.00              2          1               1
# 8        4  142051.07              2          0               1
# 9        2  134603.88              1          1               1
# 10       6  102016.72              2          0               0
#
#     EstimatedSalary  Exited
# 5         149756.71       1
# 6          10062.80       0
# 8          74940.50       0
# 9          71725.73       0
# ...

# %%
# Gender == female

female = mall[mall["Gender"] == 'Female']
print(female.head())
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
# age > 40 & numOfProducts == 3


age_pro = mall[(mall['Age'] > 40) & (mall['NumOfProducts'] == 3) & (mall["Gender"] == 'Male') & (mall["Geography"] == "France")]

print(age_pro)
# Out:
#       RowNumber  CustomerId        Surname  CreditScore Geography Gender  Age  \
# 922         923    15753337         Yeates          555    France   Male   51
# 1210       1211    15658969           Gray          711    France   Male   51
# 1376       1377    15587233       Donoghue          457    France   Male   41
# 1614       1615    15646037      Sopuluchi          641    France   Male   77
# 2104       2105    15719561            Lin          768    France   Male   42
# 2546       2547    15755178          Ramos          660    France   Male   50
# 2787       2788    15700487  Osonduagwuike          805    France   Male   46
# 2988       2989    15684801         Abbott          689    France   Male   47
# 3615       3616    15639357          Allan          415    France   Male   46
# 4136       4137    15757952           Teng          651    France   Male   44
# 4174       4175    15810593         Forbes          568    France   Male   51
# ...

# %% [markdown]
# ***

# %% [markdown]
# # Subsetting rows by categorical variables
# Subsetting data based on a categorical variable often involves using the "or" operator (|) to select rows from multiple categories. This can get tedious when you want all states in one of three different regions, for example. Instead, use the .isin() method, which will allow you to tackle this problem by writing one condition instead of three separate ones.
# <br>
# colors = ["brown", "black", "tan"]<br>
# condition = dogs["color"].isin(colors)<br>
# dogs[condition]<br>

# %% [markdown]
# # age > 40 OR(|) numOfProducts == 3

# %%
geo = mall[(mall['Geography'] == "Spain") | (mall['Geography'] == "France")]

# %%
print(geo.head(10))
# Out:
#     RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0           1    15634602  Hargrave          619    France  Female   42
# 1           2    15647311      Hill          608     Spain  Female   41
# 2           3    15619304      Onio          502    France  Female   42
# 3           4    15701354      Boni          699    France  Female   39
# 4           5    15737888  Mitchell          850     Spain  Female   43
# 5           6    15574012       Chu          645     Spain    Male   44
# 6           7    15592531  Bartlett          822    France    Male   50
# 8           9    15792365        He          501    France    Male   44
# 9          10    15592389        H?          684    France    Male   27
# 10         11    15767821    Bearce          528    France    Male   31
#
#     Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0        2       0.00              1          1               1
# ...

# %%
# The Mojave Desert states
canu = ["California", "Arizona", "Nevada", "Utah"]

geos = mall[mall["Geography"].isin(canu)]

# %%
print(geo)
# Out:
#       RowNumber  CustomerId        Surname  CreditScore Geography  Gender  \
# 0             1    15634602       Hargrave          619    France  Female
# 1             2    15647311           Hill          608     Spain  Female
# 2             3    15619304           Onio          502    France  Female
# 3             4    15701354           Boni          699    France  Female
# 4             5    15737888       Mitchell          850     Spain  Female
# 5             6    15574012            Chu          645     Spain    Male
# 6             7    15592531       Bartlett          822    France    Male
# 8             9    15792365             He          501    France    Male
# 9            10    15592389             H?          684    France    Male
# 10           11    15767821         Bearce          528    France    Male
# 11           12    15737173        Andrews          497     Spain    Male
# 12           13    15632264            Kay          476    France  Female
# ...

# %% [markdown]
# ***

# %% [markdown]
# # Creating and Adding New Columns

# %%
# salary - balance

mall['money_used'] = mall['EstimatedSalary'] - mall["Balance"]

print(mall.head(10))
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
# 5          6    15574012       Chu          645     Spain    Male   44
# 6          7    15592531  Bartlett          822    France    Male   50
# 7          8    15656148    Obinna          376   Germany  Female   29
# 8          9    15792365        He          501    France    Male   44
# 9         10    15592389        H?          684    France    Male   27
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# ...

# %%
mall[['money_used', 'EstimatedSalary']]
# Out:
#       money_used  EstimatedSalary
# 0      101348.88        101348.88
# 1       28734.72        112542.58
# 2      -45729.23        113931.57
# 3       93826.63         93826.63
# 4      -46426.72         79084.10
# 5       36000.93        149756.71
# 6       10062.80         10062.80
# 7        4300.14        119346.88
# 8      -67110.57         74940.50
# 9      -62878.15         71725.73
# 10     -21835.60         80181.12
# 11      76390.01         76390.01
# 12      26260.98         26260.98
# 13     190857.79        190857.79
# 14      65951.65         65951.65
# 15     -78802.15         64327.26
# 16    -127505.21          5097.67
# 17      14406.41         14406.41
# 18     158684.81        158684.81
# 19      54724.03         54724.03
# 20     170886.17        170886.17
# 21     138555.46        138555.46
# 22     118913.53        118913.53
# 23       8487.75          8487.75
# 24     187616.16        187616.16
# 25     124508.29        124508.29
# ...
