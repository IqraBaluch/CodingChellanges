# %% [markdown]
# # Pandas (WORKING WITH TABULAR DATA)

# %% [markdown]
# # LOAD CSV DATA

# %%
# import package
import pandas as pd

data = pd.read_csv("Desktop/pokemon_data.csv")

# %%
print(data)
# Out:
#        #                       Name    Type 1  Type 2   HP  Attack  Defense  \
# 0      1                  Bulbasaur     Grass  Poison   45      49       49
# 1      2                    Ivysaur     Grass  Poison   60      62       63
# 2      3                   Venusaur     Grass  Poison   80      82       83
# 3      3      VenusaurMega Venusaur     Grass  Poison   80     100      123
# 4      4                 Charmander      Fire     NaN   39      52       43
# 5      5                 Charmeleon      Fire     NaN   58      64       58
# 6      6                  Charizard      Fire  Flying   78      84       78
# 7      6  CharizardMega Charizard X      Fire  Dragon   78     130      111
# 8      6  CharizardMega Charizard Y      Fire  Flying   78     104       78
# 9      7                   Squirtle     Water     NaN   44      48       65
# 10     8                  Wartortle     Water     NaN   59      63       80
# ...

# %%
# print top 5 ros
data.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# # LOAD EXCEL DATA

# %%
data_excel = pd.read_excel("Desktop/pokemon_data.xlsx")
data_excel.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# # LOAD TEXT DATA

# %%
# load text data without , delimiter='\t'
data_txt = pd.read_csv("Desktop/pokemon_data.txt")
data_txt.head()
# Out:
#   #\tName\tType 1\tType 2\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 0  1\tBulbasaur\tGrass\tPoison\t45\t49\t49\t65\t6...
# 1  2\tIvysaur\tGrass\tPoison\t60\t62\t63\t80\t80\...
# 2  3\tVenusaur\tGrass\tPoison\t80\t82\t83\t100\t1...
# 3  3\tVenusaurMega Venusaur\tGrass\tPoison\t80\t1...
# 4  4\tCharmander\tFire\t\t39\t52\t43\t60\t50\t65\...

# %%
# load text data with , delimiter='\t'
data_txt = pd.read_csv("Desktop/pokemon_data.txt", delimiter='\t')
data_txt.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# # Reading Data with pandas
# ### Header of Data / Columns

# %%
data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# ### read spacific columns

# %%
#name column from data
name_column = data['Name']
name_column
# Out:
# 0                      Bulbasaur
# 1                        Ivysaur
# 2                       Venusaur
# 3          VenusaurMega Venusaur
# 4                     Charmander
# 5                     Charmeleon
# 6                      Charizard
# 7      CharizardMega Charizard X
# 8      CharizardMega Charizard Y
# 9                       Squirtle
# 10                     Wartortle
# 11                     Blastoise
# 12       BlastoiseMega Blastoise
# 13                      Caterpie
# 14                       Metapod
# 15                    Butterfree
# 16                        Weedle
# 17                        Kakuna
# 18                      Beedrill
# 19         BeedrillMega Beedrill
# 20                        Pidgey
# 21                     Pidgeotto
# 22                       Pidgeot
# 23           PidgeotMega Pidgeot
# 24                       Rattata
# 25                      Raticate
# 26                       Spearow
# 27                        Fearow
# ...

# %%
# top 10 names
name = data['Name'][:10 ]
name
# Out:
# 0                    Bulbasaur
# 1                      Ivysaur
# 2                     Venusaur
# 3        VenusaurMega Venusaur
# 4                   Charmander
# 5                   Charmeleon
# 6                    Charizard
# 7    CharizardMega Charizard X
# 8    CharizardMega Charizard Y
# 9                     Squirtle
# Name: Name, dtype: object

# %%
# last 10 names
name = data['Name'][-10:-1]
name
# Out:
# 790                 Noibat
# 791                Noivern
# 792                Xerneas
# 793                Yveltal
# 794       Zygarde50% Forme
# 795                Diancie
# 796    DiancieMega Diancie
# 797    HoopaHoopa Confined
# 798     HoopaHoopa Unbound
# Name: Name, dtype: object

# %%
hp = data['HP']
hp
# Out:
# 0       45
# 1       60
# 2       80
# 3       80
# 4       39
# 5       58
# 6       78
# 7       78
# 8       78
# 9       44
# 10      59
# 11      79
# 12      79
# 13      45
# 14      50
# 15      60
# 16      40
# 17      45
# 18      65
# 19      65
# 20      40
# 21      63
# 22      83
# 23      83
# 24      30
# 25      55
# 26      40
# 27      65
# 28      35
# 29      60
#       ...
# 770     95
# 771     78
# 772     67
# 773     50
# 774     45
# 775     68
# 776     90
# 777     57
# 778     43
# 779     85
# 780     49
# 781     44
# 782     54
# 783     59
# 784     65
# 785     55
# 786     75
# 787     85
# 788     55
# 789     95
# 790     40
# 791     85
# 792    126
# 793    126
# 794    108
# 795     50
# 796     50
# 797     80
# 798     80
# 799     80
# Name: HP, Length: 800, dtype: int64

# %%
hp1 = data['HP'][0:11]
hp1
# Out:
# 0     45
# 1     60
# 2     80
# 3     80
# 4     39
# 5     58
# 6     78
# 7     78
# 8     78
# 9     44
# 10    59
# Name: HP, dtype: int64

# %%
typ1 = data['Type 1'][-5:-1]
typ1
# Out:
# 795       Rock
# 796       Rock
# 797    Psychic
# 798    Psychic
# Name: Type 1, dtype: object

# %%
typ1 = data['Type 1'][5:10]
typ1
# Out:
# 5     Fire
# 6     Fire
# 7     Fire
# 8     Fire
# 9    Water
# Name: Type 1, dtype: object

# %%
typ1 = data['Type 1'][-50:-41]
typ1
# Out:
# 750    Steel
# 751    Steel
# 752    Fairy
# 753    Fairy
# 754    Fairy
# 755    Fairy
# 756     Dark
# 757     Dark
# 758     Rock
# Name: Type 1, dtype: object

# %%
typ2 = data['Type 2']
typ2.head()
# Out:
# 0    Poison
# 1    Poison
# 2    Poison
# 3    Poison
# 4       NaN
# Name: Type 2, dtype: object

# %%
data['Type 2'][5:15]
# Out:
# 5        NaN
# 6     Flying
# 7     Dragon
# 8     Flying
# 9        NaN
# 10       NaN
# 11       NaN
# 12       NaN
# 13       NaN
# 14       NaN
# Name: Type 2, dtype: object

# %% [markdown]
# # Slicing on dataFrame

# %%
data[-10:-2]
# Out:
#        #                 Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 790  714               Noibat   Flying  Dragon   40      30       35       45
# 791  715              Noivern   Flying  Dragon   85      70       80       97
# 792  716              Xerneas    Fairy     NaN  126     131       95      131
# 793  717              Yveltal     Dark  Flying  126     131       95      131
# 794  718     Zygarde50% Forme   Dragon  Ground  108     100      121       81
# 795  719              Diancie     Rock   Fairy   50     100      150      100
# 796  719  DiancieMega Diancie     Rock   Fairy   50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic   Ghost   80     110       60      150
#
#      Sp. Def  Speed  Generation  Legendary
# 790       40     55           6      False
# 791       80    123           6      False
# 792       98     99           6       True
# 793       98     99           6       True
# 794       95     95           6       True
# ...

# %%
data[50:55]
# Out:
#      #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 50  45  Vileplume  Grass  Poison  75      80       85      110       90
# 51  46      Paras    Bug   Grass  35      70       55       45       55
# 52  47   Parasect    Bug   Grass  60      95       80       60       80
# 53  48    Venonat    Bug  Poison  60      55       50       40       55
# 54  49   Venomoth    Bug  Poison  70      65       60       90       75
#
#     Speed  Generation  Legendary
# 50     50           1      False
# 51     25           1      False
# 52     30           1      False
# 53     45           1      False
# 54     90           1      False

# %%
data[502:511]
# Out:
#        #       Name  Type 1    Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 502  452    Drapion  Poison      Dark  70      90      110       60       75
# 503  453   Croagunk  Poison  Fighting  48      61       40       61       40
# 504  454  Toxicroak  Poison  Fighting  83     106       65       86       65
# 505  455  Carnivine   Grass       NaN  74     100       72       90       72
# 506  456    Finneon   Water       NaN  49      49       56       49       61
# 507  457   Lumineon   Water       NaN  69      69       76       69       86
# 508  458    Mantyke   Water    Flying  45      20       50       60      120
# 509  459     Snover   Grass       Ice  60      62       50       62       60
# 510  460  Abomasnow   Grass       Ice  90      92       75       92       85
#
#      Speed  Generation  Legendary
# 502     95           4      False
# 503     50           4      False
# 504     85           4      False
# 505     46           4      False
# ...

# %% [markdown]
# # Row

# %%
#iloc function
row_0 = data.iloc[0]
row_0
# Out:
# #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object

# %%
row3_10 = data.iloc[3:10]
row3_10
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 3      120     80           1      False
# 4       50     65           1      False
# 5       65     80           1      False
# 6       85    100           1      False
# 7       85    100           1      False
# 8      115    100           1      False
# 9       64     43           1      False

# %%
last_row = data.iloc[-1]
last_row
# Out:
# #                   721
# Name          Volcanion
# Type 1             Fire
# Type 2            Water
# HP                   80
# Attack              110
# Defense             120
# Sp. Atk             130
# Sp. Def              90
# Speed                70
# Generation            6
# Legendary          True
# Name: 799, dtype: object

# %%
#iloc function is used for spacific attribute
data.iloc[5,1]
# Out:
# 'Charmeleon'

# %%
data.iloc[-1,2]
# Out:
# 'Fire'

# %%
data.iloc[-1,1]
# Out:
# 'Volcanion'

# %%
data.iloc[-1,3]
# Out:
# 'Water'

# %%
data.iloc[-1,-1]
# Out:
# True

# %% [markdown]
# ## for loop

# %%
for header, attributes in data.iterrows():
    print(header, attributes)
# Out:
# 0 #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object
# 1 #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object
# 2 #                    3
# Name          Venusaur
# Type 1           Grass
# Type 2          Poison
# HP                  80
# Attack              82
# Defense             83
# Sp. Atk            100
# Sp. Def            100
# Speed               80
# Generation           1
# Legendary        False
# Name: 2, dtype: object
# ...

# %%
list1 = []
for index, column in data.iterrows():
    list1.append(index)
    list1.append(column)

# %%
list1
# Out:
# [0, #                     1
#  Name          Bulbasaur
#  Type 1            Grass
#  Type 2           Poison
#  HP                   45
#  Attack               49
#  Defense              49
#  Sp. Atk              65
#  Sp. Def              65
#  Speed                45
#  Generation            1
#  Legendary         False
#  Name: 0, dtype: object, 1, #                   2
#  Name          Ivysaur
#  Type 1          Grass
#  Type 2         Poison
#  HP                 60
#  Attack             62
#  Defense            63
#  Sp. Atk            80
#  Sp. Def            80
#  Speed              60
#  Generation          1
#  Legendary       False
#  Name: 1, dtype: object, 2, #                    3
#  Name          Venusaur
#  Type 1           Grass
#  Type 2          Poison
#  HP                  80
#  Attack              82
#  Defense             83
#  Sp. Atk            100
#  Sp. Def            100
#  Speed               80
#  Generation           1
#  Legendary        False
# ...

# %% [markdown]
# #### Numerical data
# ### Relational data

# %%
data.loc[data['Type 2'] =='Fire']
# Out:
#        #                   Name    Type 1 Type 2   HP  Attack  Defense  \
# 246  228               Houndour      Dark   Fire   45      60       30
# 247  229               Houndoom      Dark   Fire   75      90       50
# 248  229  HoundoomMega Houndoom      Dark   Fire   75      90       90
# 424  383  GroudonPrimal Groudon    Ground   Fire  100     180      160
# 532  479        RotomHeat Rotom  Electric   Fire   50      65      107
# 553  494                Victini   Psychic   Fire  100     100      100
# 668  607                Litwick     Ghost   Fire   50      30       55
# 669  608                Lampent     Ghost   Fire   60      40       60
# 670  609             Chandelure     Ghost   Fire   60      55       90
# 697  636               Larvesta       Bug   Fire   55      85       55
# 698  637              Volcarona       Bug   Fire   85      60       65
# 706  643               Reshiram    Dragon   Fire  100     120      100
#
# ...

# %%
data.loc[data['HP'] <= 40]
# Out:
#        #        Name    Type 1   Type 2  HP  Attack  Defense  Sp. Atk  \
# 4      4  Charmander      Fire      NaN  39      52       43       60
# 16    13      Weedle       Bug   Poison  40      35       30       20
# 20    16      Pidgey    Normal   Flying  40      45       40       35
# 24    19     Rattata    Normal      NaN  30      56       35       25
# 26    21     Spearow    Normal   Flying  40      60       30       31
# 28    23       Ekans    Poison      NaN  35      60       44       40
# 30    25     Pikachu  Electric      NaN  35      55       40       50
# 42    37      Vulpix      Fire      NaN  38      41       40       50
# 46    41       Zubat    Poison   Flying  40      45       35       30
# 51    46       Paras       Bug    Grass  35      70       55       45
# 55    50     Diglett    Ground      NaN  10      55       25       35
# 56    51     Dugtrio    Ground      NaN  35      80       50       50
# ...

# %% [markdown]
# ## Multiple Conditions with loc funvtion

# %%
data.loc[(data['Type 2']== 'Flying') & (data['Type 1'] == 'Bug' )& (data['Attack'] <= 45)]
# Out:
#        #        Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 15    12  Butterfree    Bug  Flying  60      45       50       90       80
# 179  165      Ledyba    Bug  Flying  40      20       30       40       80
# 180  166      Ledian    Bug  Flying  55      35       50       55      110
# 462  415      Combee    Bug  Flying  30      30       42       30       42
#
#      Speed  Generation  Legendary
# 15      70           1      False
# 179     55           2      False
# 180     85           2      False
# 462     70           4      False

# %% [markdown]
# ## Sort

# %%
loc_new = data.loc[(data['HP']>=90)&(data['Speed']==70)&(data['Generation']<=4)]

# %%
loc_new.sort_values(['HP', 'Generation'], ascending=[1,1])
# Out:
#        #                   Name  Type 1    Type 2   HP  Attack  Defense  \
# 67    62              Poliwrath   Water  Fighting   90      95       95
# 94    87                Dewgong   Water       Ice   90      70       80
# 201  186               Politoed   Water       NaN   90      75       75
# 472  425               Drifloon   Ghost    Flying   90      50       34
# 178  164                Noctowl  Normal    Flying  100      50       50
# 283  260  SwampertMega Swampert   Water    Ground  100     150      110
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 67        70       90     70           1      False
# 94        70       95     70           1      False
# 201       90      100     70           2      False
# 472       60       44     70           4      False
# 178       76       96     70           2      False
# 283       95      110     70           3      False

# %% [markdown]
# # Making Changes to the Data

# %%
data.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# ## Adding New Column

# %%
data['Total'] = data['HP'] + data['Defense'] + data['Speed'] + data['Attack'] + data['Sp. Atk']

# %%
data.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    253
# 1       80     60           1      False    325
# 2      100     80           1      False    425
# 3      120     80           1      False    505
# 4       50     65           1      False    259

# %%
data['Grass'] = data['Type 1'] == 'Grass'

# %%
data.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total  Grass
# 0       65     45           1      False    253   True
# 1       80     60           1      False    325   True
# 2      100     80           1      False    425   True
# 3      120     80           1      False    505   True
# 4       50     65           1      False    259  False

# %% [markdown]
# ## Adding New Column 2

# %%
data["Totals"] = data.iloc[:,4:10].sum(axis=1)
data.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total  Totals
# 0       65     45           1      False    253     318
# 1       80     60           1      False    325     405
# 2      100     80           1      False    425     525
# 3      120     80           1      False    505     625
# 4       50     65           1      False    259     309

# %% [markdown]
# ### Drop Any Column

# %%
data = data.drop(columns=['Grass'])

# %%
data.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total  Totals
# 0       65     45           1      False    253     318
# 1       80     60           1      False    325     405
# 2      100     80           1      False    425     525
# 3      120     80           1      False    505     625
# 4       50     65           1      False    259     309

# %%
## Column Customization/ changing places of columns

# %%
cols = list(data.columns.values)
data = data[cols[0:5]+[cols[-1]]+ [cols[-2]]+cols[5:10]]

# %%
data.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Sp. Atk  Defense  Speed  \
# 0  1              Bulbasaur  Grass  Poison  45       65       49     45
# 1  2                Ivysaur  Grass  Poison  60       80       63     60
# 2  3               Venusaur  Grass  Poison  80      100       83     80
# 3  3  VenusaurMega Venusaur  Grass  Poison  80      122      123     80
# 4  4             Charmander   Fire     NaN  39       60       43     65
#
#    Speed  Speed  ...    Speed  Speed  Speed  Speed  Sp. Def  Generation  \
# 0     45     45  ...       45     45     45     45       65           1
# 1     60     60  ...       60     60     60     60       80           1
# 2     80     80  ...       80     80     80     80      100           1
# 3     80     80  ...       80     80     80     80      120           1
# 4     65     65  ...       65     65     65     65       50           1
#
#    Speed  Speed  Speed  Speed
# 0     45     45     45     45
# 1     60     60     60     60
# ...

# %%
data = data.drop(columns=['Speed'])

# %%
data.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Sp. Atk  Defense  Sp. Def  \
# 0  1              Bulbasaur  Grass  Poison  45       65       49       65
# 1  2                Ivysaur  Grass  Poison  60       80       63       80
# 2  3               Venusaur  Grass  Poison  80      100       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80      122      123      120
# 4  4             Charmander   Fire     NaN  39       60       43       50
#
#    Generation
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %% [markdown]
# # Text File

# %%
data.to_csv('modify.txt', index = False, sep = '\t')

# %% [markdown]
# ## Filtering Data

# %%
data.loc[(data['Type 1']== 'Grass') & (data['Type 2']== 'Poison')]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 48    43                 Oddish  Grass  Poison   45      50       55       75
# 49    44                  Gloom  Grass  Poison   60      65       70       85
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 75    69             Bellsprout  Grass  Poison   50      75       35       70
# 76    70             Weepinbell  Grass  Poison   65      90       50       85
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 344  315                Roselia  Grass  Poison   50      60       45      100
# ...

# %%
data.loc[(data['Type 1']== 'Grass') | (data['Type 2']== 'Poison')]
# Out:
#        #                     Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1                Bulbasaur  Grass    Poison   45      49       49
# 1      2                  Ivysaur  Grass    Poison   60      62       63
# 2      3                 Venusaur  Grass    Poison   80      82       83
# 3      3    VenusaurMega Venusaur  Grass    Poison   80     100      123
# 16    13                   Weedle    Bug    Poison   40      35       30
# 17    14                   Kakuna    Bug    Poison   45      25       50
# 18    15                 Beedrill    Bug    Poison   65      90       40
# 19    15    BeedrillMega Beedrill    Bug    Poison   65     150       40
# 48    43                   Oddish  Grass    Poison   45      50       55
# 49    44                    Gloom  Grass    Poison   60      65       70
# 50    45                Vileplume  Grass    Poison   75      80       85
# 53    48                  Venonat    Bug    Poison   60      55       50
# ...

# %%
new_filter_data = data.loc[(data['Type 1']== 'Grass') & (data['Type 2']== 'Poison') & (data['HP'] > 70)]

#new_filter_data.to_csv('filter.csv')
new_filter_data
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 652  591              Amoonguss  Grass  Poison  114      85       70       85
#
#      Sp. Def  Speed  Generation  Legendary
# 2        100     80           1      False
# 3        120     80           1      False
# 50        90     50           1      False
# 77        70     70           1      False
# 652       80     30           5      False

# %% [markdown]
# ### Customised Index

# %%
# index starts at 0
new_filter_data.reset_index()
# Out:
#    index    #                   Name Type 1  Type 2   HP  Attack  Defense  \
# 0      2    3               Venusaur  Grass  Poison   80      82       83
# 1      3    3  VenusaurMega Venusaur  Grass  Poison   80     100      123
# 2     50   45              Vileplume  Grass  Poison   75      80       85
# 3     77   71             Victreebel  Grass  Poison   80     105       65
# 4    652  591              Amoonguss  Grass  Poison  114      85       70
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0      100      100     80           1      False
# 1      122      120     80           1      False
# 2      110       90     50           1      False
# 3      100       70     70           1      False
# 4       85       80     30           5      False

# %% [markdown]
# ## remove old index

# %%
new_filter_data.reset_index(drop = True, inplace=True)
new_filter_data
# Out:
#      #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0    3               Venusaur  Grass  Poison   80      82       83      100
# 1    3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 2   45              Vileplume  Grass  Poison   75      80       85      110
# 3   71             Victreebel  Grass  Poison   80     105       65      100
# 4  591              Amoonguss  Grass  Poison  114      85       70       85
#
#    Sp. Def  Speed  Generation  Legendary
# 0      100     80           1      False
# 1      120     80           1      False
# 2       90     50           1      False
# 3       70     70           1      False
# 4       80     30           5      False

# %% [markdown]
# ## name containing spacific word

# %%
data.loc[data['Name'].str.contains('Mega')]
# Out:
#        #                       Name    Type 1    Type 2   HP  Attack  Defense  \
# 3      3      VenusaurMega Venusaur     Grass    Poison   80     100      123
# 7      6  CharizardMega Charizard X      Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y      Fire    Flying   78     104       78
# 12     9    BlastoiseMega Blastoise     Water       NaN   79     103      120
# 19    15      BeedrillMega Beedrill       Bug    Poison   65     150       40
# 23    18        PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 71    65      AlakazamMega Alakazam   Psychic       NaN   55      50       65
# 87    80        SlowbroMega Slowbro     Water   Psychic   95      75      180
# 102   94          GengarMega Gengar     Ghost    Poison   60      65       80
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN  105     125      100
# 137  127          PinsirMega Pinsir       Bug    Flying   65     155      120
# ...

# %% [markdown]
# ## Drop row that contains spasific word

# %%
data[~data['Name'].str.contains('Mega')]
# Out:
#        #                   Name    Type 1  Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur     Grass  Poison   45      49       49
# 1      2                Ivysaur     Grass  Poison   60      62       63
# 2      3               Venusaur     Grass  Poison   80      82       83
# 4      4             Charmander      Fire     NaN   39      52       43
# 5      5             Charmeleon      Fire     NaN   58      64       58
# 6      6              Charizard      Fire  Flying   78      84       78
# 9      7               Squirtle     Water     NaN   44      48       65
# 10     8              Wartortle     Water     NaN   59      63       80
# 11     9              Blastoise     Water     NaN   79      83      100
# 13    10               Caterpie       Bug     NaN   45      30       35
# 14    11                Metapod       Bug     NaN   50      20       55
# 15    12             Butterfree       Bug  Flying   60      45       50
# ...

# %% [markdown]
# ## Regular Expressions

# %%
import re
data.loc[data['Type 1'].str.contains('Fire|Grass', regex= True)]
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1                  Bulbasaur  Grass    Poison   45      49       49
# 1      2                    Ivysaur  Grass    Poison   60      62       63
# 2      3                   Venusaur  Grass    Poison   80      82       83
# 3      3      VenusaurMega Venusaur  Grass    Poison   80     100      123
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# ...

# %% [markdown]
# ## Ignore capatalization

# %%
data.loc[data['Type 1'].str.contains('fire|grass',flags=re.I, regex= True)]
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1                  Bulbasaur  Grass    Poison   45      49       49
# 1      2                    Ivysaur  Grass    Poison   60      62       63
# 2      3                   Venusaur  Grass    Poison   80      82       83
# 3      3      VenusaurMega Venusaur  Grass    Poison   80     100      123
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# ...

# %% [markdown]
# ## Pokemen name that sart with (pi)

# %%
data.loc[data['Name'].str.contains('pi|a[a-z]*', flags=re.I, regex=True)]
# Out:
#        #                       Name    Type 1  Type 2   HP  Attack  Defense  \
# 0      1                  Bulbasaur     Grass  Poison   45      49       49
# 1      2                    Ivysaur     Grass  Poison   60      62       63
# 2      3                   Venusaur     Grass  Poison   80      82       83
# 3      3      VenusaurMega Venusaur     Grass  Poison   80     100      123
# 4      4                 Charmander      Fire     NaN   39      52       43
# 5      5                 Charmeleon      Fire     NaN   58      64       58
# 6      6                  Charizard      Fire  Flying   78      84       78
# 7      6  CharizardMega Charizard X      Fire  Dragon   78     130      111
# 8      6  CharizardMega Charizard Y      Fire  Flying   78     104       78
# 10     8                  Wartortle     Water     NaN   59      63       80
# 11     9                  Blastoise     Water     NaN   79      83      100
# ...
