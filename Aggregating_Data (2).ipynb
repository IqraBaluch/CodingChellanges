# %% [markdown]
# # Agrigating Data

# %% [markdown]
# # Day11-Summary Statistics
# mean, median, minimum, maximum, and standard deviation are summary statistics.

# %% [markdown]
# ***

# %% [markdown]
# # Python Package
# import libraray

# %%
import pandas as pd

# %% [markdown]
# # Access tabular data by pandas

# %%
superstore = pd.read_csv("Desktop/Superstore_Sales_Dataset.csv")

# %%
print(superstore.head(10))
# Out:
#    Row_ID        Order_ID  Order_Date   Ship_Date       Ship+Mode Customer_ID  \
# 0       1  CA-2017-152156   8/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156   8/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688   12/6/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 5       6  CA-2015-115812    9/6/2015  14/06/2015  Standard Class    BH-11710
# 6       7  CA-2015-115812    9/6/2015  14/06/2015  Standard Class    BH-11710
# 7       8  CA-2015-115812    9/6/2015  14/06/2015  Standard Class    BH-11710
# 8       9  CA-2015-115812    9/6/2015  14/06/2015  Standard Class    BH-11710
# 9      10  CA-2015-115812    9/6/2015  14/06/2015  Standard Class    BH-11710
#
#      Customer_Name    Segment        Country             City       State  \
# ...

# %% [markdown]
# # Inspecting Dataset

# %%
print(superstore.head())
# Out:
#    Row_ID        Order_ID  Order_Date   Ship_Date       Ship+Mode Customer_ID  \
# 0       1  CA-2017-152156   8/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156   8/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688   12/6/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
print(superstore.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
# Row_ID           9800 non-null int64
# Order_ID         9800 non-null object
# Order_Date       9800 non-null object
# Ship_Date        9800 non-null object
# Ship+Mode        9800 non-null object
# Customer_ID      9800 non-null object
# Customer_Name    9800 non-null object
# Segment          9800 non-null object
# Country          9800 non-null object
# City             9800 non-null object
# State            9800 non-null object
# Postal_Code      9789 non-null float64
# Region           9800 non-null object
# Product_ID       9800 non-null object
# Category         9800 non-null object
# Sub_Category     9800 non-null object
# Product_Name     9800 non-null object
# Sales            9800 non-null float64
# dtypes: float64(2), int64(1), object(15)
# memory usage: 1.3+ MB
# None

# %%
print(superstore.shape)
# Out:
# (9800, 18)

# %%
print(superstore.describe())
# Out:
#             Row_ID   Postal_Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %%
print(superstore.columns)
# Out:
# Index(['Row_ID', 'Order_ID', 'Order_Date', 'Ship_Date', 'Ship+Mode',
#        'Customer_ID', 'Customer_Name', 'Segment', 'Country', 'City', 'State',
#        'Postal_Code', 'Region', 'Product_ID', 'Category', 'Sub_Category',
#        'Product_Name', 'Sales'],
#       dtype='object')

# %% [markdown]
# # Mean and median
#
# # Print the mean of the sales column.

# %%
#mean is center of data
print(superstore['Sales'].mean())
# Out:
# 230.76905945917886

# %% [markdown]
# # Print the median of the sales column.

# %%
# The middle number; found by ordering all data points and picking out the one in the middle 
#(or if there are two middle numbers, taking the mean of those
print(superstore['Sales'].median())
# Out:
# 54.489999999999995

# %% [markdown]
# # Summarizing dates

# %% [markdown]
# # Order_date

# %% [markdown]
# ## Print the maximum of the order date column.

# %%
print(superstore["Order_Date"].max())
# Out:
# 9/9/2018

# %% [markdown]
# ## Print the minimum of the order date column.

# %%
print(superstore['Order_Date'].min())
# Out:
# 1/1/2018

# %% [markdown]
# # Ship_Date

# %%
print(superstore["Ship_Date"].max())
# Out:
# 9/9/2018

# %%
print(superstore["Ship_Date"].min())
# Out:
# 1/1/2016

# %% [markdown]
# # .agg()
#
# The .agg() method allows you to apply your own custom functions to a DataFrame, as well as apply functions to more than one column of a DataFrame at once, making your aggregations super-efficient. For example,
# <br>
# df['column'].agg(function)

# %% [markdown]
# n the custom function for this exercise, "IQR" is short for inter-quartile range, which is the 75th percentile minus the 25th percentile. It's an alternative to standard deviation that is helpful if your data contains outliers.

# %%
# A custom IQR function
def iqr(column):
    return column.quantile(0.75) - column.quantile(0.25)
    
# Print IQR of the Sales column
print(superstore["Sales"].agg(iqr))
# Out:
# 193.35700000000003

# %% [markdown]
# # Cumulative statistics

# %%
# Sort the rows of sale by the date column in ascending order.
order_date = superstore.sort_values("Order_Date")

print(order_date.head())
# Out:
#       Row_ID        Order_ID Order_Date Ship_Date       Ship+Mode Customer_ID  \
# 4009    4010  CA-2018-144463   1/1/2018  5/1/2018  Standard Class    SC-20725
# 8069    8070  CA-2018-151750   1/1/2018  5/1/2018  Standard Class    JM-15250
# 6682    6683  CA-2018-154466   1/1/2018  2/1/2018     First Class    DP-13390
# 8070    8071  CA-2018-151750   1/1/2018  5/1/2018  Standard Class    JM-15250
# 8075    8076  CA-2018-151750   1/1/2018  5/1/2018  Standard Class    JM-15250
#
#           Customer_Name      Segment        Country         City       State  \
# 4009  Steven Cartwright     Consumer  United States  Los Angeles  California
# 8069       Janet Martin     Consumer  United States   Huntsville       Texas
# 6682      Dennis Pardue  Home Office  United States     Franklin   Wisconsin
# 8070       Janet Martin     Consumer  United States   Huntsville       Texas
# 8075       Janet Martin     Consumer  United States   Huntsville       Texas
#
# ...

# %%
sales = superstore['Sales'].cumsum()
print(sales.head())
# Out:
# 0     261.9600
# 1     993.9000
# 2    1008.5200
# 3    1966.0975
# 4    1988.4655
# Name: Sales, dtype: float64

# %%
sale = superstore['Sales'].cummax()
print(sale.head())
# Out:
# 0    261.9600
# 1    731.9400
# 2    731.9400
# 3    957.5775
# 4    957.5775
# Name: Sales, dtype: float64

# %% [markdown]
# ****

# %% [markdown]
# # Day12- Counting
# summarizing categorical data

# %% [markdown]
# # Dropping duplicates
# Removing duplicates is an essential skill to get accurate counts because often, you don't want to count the same thing multiple times.

# %% [markdown]
# # Remove rows of superstore with duplicate pairs of suctomerID and Customer_name and save as namr_id and print the head.

# %%
name_id =  superstore.drop_duplicates(subset=['Customer_ID','Customer_Name'])
print(name_id.head())
# Out:
#     Row_ID        Order_ID  Order_Date   Ship_Date       Ship+Mode  \
# 0        1  CA-2017-152156   8/11/2017  11/11/2017    Second Class
# 2        3  CA-2017-138688   12/6/2017  16/06/2017    Second Class
# 3        4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 5        6  CA-2015-115812    9/6/2015  14/06/2015  Standard Class
# 12      13  CA-2018-114412  15/04/2018  20/04/2018  Standard Class
#
#    Customer_ID    Customer_Name    Segment        Country             City  \
# 0     CG-12520      Claire Gute   Consumer  United States        Henderson
# 2     DV-13045  Darrin Van Huff  Corporate  United States      Los Angeles
# 3     SO-20335   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 5     BH-11710  Brosina Hoffman   Consumer  United States      Los Angeles
# 12    AA-10480     Andrew Allen   Consumer  United States          Concord
#
#              State  Postal_Code Region       Product_ID         Category  \
# ...

# %% [markdown]
# #  Remove rows of superstore with duplicate pairs of country and city and save as country_city and print the head.

# %%
country_city = superstore.drop_duplicates(subset=['Country', 'City'])
print(country_city.head())
# Out:
#     Row_ID        Order_ID  Order_Date   Ship_Date       Ship+Mode  \
# 0        1  CA-2017-152156   8/11/2017  11/11/2017    Second Class
# 2        3  CA-2017-138688   12/6/2017  16/06/2017    Second Class
# 3        4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 12      13  CA-2018-114412  15/04/2018  20/04/2018  Standard Class
# 13      14  CA-2017-161389   5/12/2017  10/12/2017  Standard Class
#
#    Customer_ID    Customer_Name    Segment        Country             City  \
# 0     CG-12520      Claire Gute   Consumer  United States        Henderson
# 2     DV-13045  Darrin Van Huff  Corporate  United States      Los Angeles
# 3     SO-20335   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 12    AA-10480     Andrew Allen   Consumer  United States          Concord
# 13    IM-15070     Irene Maddox   Consumer  United States          Seattle
#
#              State  Postal_Code Region       Product_ID         Category  \
# ...

# %% [markdown]
# # Count the number of City

# %%
orderID_count = superstore['City'].value_counts()

# %%
print(orderID_count)
# Out:
# New York City      891
# Los Angeles        728
# Philadelphia       532
# San Francisco      500
# Seattle            426
# Houston            374
# Chicago            308
# Columbus           221
# San Diego          170
# Springfield        161
# Dallas             156
# Jacksonville       125
# Detroit            115
# Newark              92
# Jackson             82
# Columbia            81
# Richmond            81
# Aurora              68
# Phoenix             63
# Arlington           60
# San Antonio         59
# Miami               56
# Louisville          54
# Rochester           53
# Long Beach          52
# Charlotte           51
# Henderson           51
# Lakewood            48
# Lancaster           46
# Lawrence            44
#                   ...
# Margate              1
# Vacaville            1
# Conway               1
# Chapel Hill          1
# Deer Park            1
# Jupiter              1
# Springdale           1
# Commerce City        1
# Pensacola            1
# ...

# %% [markdown]
# # Count the number of items sold

# %%
catogary_count = superstore['Category'].value_counts()

# %%
print(catogary_count)
# Out:
# Office Supplies    5909
# Furniture          2078
# Technology         1813
# Name: Category, dtype: int64

# %% [markdown]
# # Count the number of Products separately

# %%
product_count = superstore['Product_Name'].value_counts()

# %%
print(product_count)
# Out:
# Staple envelope                                                                        47
# Staples                                                                                46
# Easy-staple paper                                                                      44
# Avery Non-Stick Binders                                                                20
# Staple remover                                                                         18
# Staples in misc. colors                                                                18
# KI Adjustable-Height Table                                                             17
# Storex Dura Pro Binders                                                                17
# Staple-based wall hangings                                                             16
# Situations Contoured Folding Chairs, 4/Set                                             15
# ...

# %% [markdown]
# # Count the number of State

# %%
state_count = superstore['State'].value_counts(sort=True,normalize=True)

# %% [markdown]
# print(state_count)

# %% [markdown]
# # Grouped summary statistics

# %% [markdown]
# # Group sales by Region

# %%
sales = superstore.groupby('Region')['Sales'].sum()

# %%
sales
# Out:
# Region
# Central    492646.9132
# East       669518.7260
# South      389151.4590
# West       710219.6845
# Name: Sales, dtype: float64

# %% [markdown]
# # group sales by Product_Name

# %%
grp_product = superstore.groupby('Product_Name')['Sales'].sum()

# %%
print(grp_product)
# Out:
# Product_Name
# "While you Were Out" Message Book, One Form per Page                                                      25.228
# #10 Gummed Flap White Envelopes, 100/Box                                                                  41.300
# #10 Self-Seal White Envelopes                                                                            108.682
# #10 White Business Envelopes,4 1/8 x 9 1/2                                                               379.214
# #10- 4 1/8" x 9 1/2" Recycled Envelopes                                                                  286.672
# #10- 4 1/8" x 9 1/2" Security-Tint Envelopes                                                             146.688
# #10-4 1/8" x 9 1/2" Premium Diagonal Seam Envelopes                                                      176.288
# #6 3/4 Gummed Flap White Envelopes                                                                        71.280
# ...

# %% [markdown]
# # group by segment

# %%
seg = superstore.groupby('Segment')['Sales'].sum()

# %%
seg
# Out:
# Segment
# Consumer       1.148061e+06
# Corporate      6.884941e+05
# Home Office    4.249822e+05
# Name: Sales, dtype: float64

# %% [markdown]
# # group by city nd Sub_Category

# %%
city_category = superstore.groupby(['City', 'Sub_Category'])['Sales'].sum()

# %%
city_category
# Out:
# City         Sub_Category
# Aberdeen     Supplies          25.500
# Abilene      Appliances         1.392
# Akron        Accessories      351.936
#              Art               22.608
#              Binders           47.166
#              Fasteners         17.184
#              Furnishings      149.232
#              Paper            134.256
#              Phones           831.066
#              Storage          886.432
#              Tables           284.364
# Albuquerque  Accessories      809.950
#              Art              255.850
#              Binders           79.872
#              Paper            365.060
#              Phones           467.088
#              Storage          242.340
# Alexandria   Art               45.920
#              Fasteners         25.060
#              Furnishings      267.460
#              Paper             49.080
#              Phones           372.320
#              Storage          595.680
#              Supplies        4164.050
# ...

# %% [markdown]
# # Multiple grouped summaries

# %% [markdown]
# # Get the min, max, mean, and median of sales for each region using .groupby() and .agg(). Store this as sales_stats. Make sure to use numpy functions!

# %%
# import numpy 
import numpy as np

# %%
sales_stats = superstore.groupby('Region')['Sales'].agg([np.min, np.max, np.mean, np.median])

# %%
sales_stats
# Out:
#           amin       amax        mean  median
# Region
# Central  0.444  17499.950  216.357889  45.920
# East     0.852  11199.968  240.401697  54.960
# South    1.167  22638.480  243.524067  54.114
# West     0.990  13999.960  226.184613  61.002

# %% [markdown]
# # # Get the min, max, mean, and median of sales for each City using .groupby() and .agg(). Store this as sales_stats. Make sure to use numpy functions!

# %%
sales_stats_city = superstore.groupby('City')['Sales'].agg([np.min, np.max, np.mean, np.median])

# %%
sales_stats_city
# Out:
#                       amin       amax        mean    median
# City
# Aberdeen            25.500    25.5000   25.500000   25.5000
# Abilene              1.392     1.3920    1.392000    1.3920
# Akron                2.286   665.4080  136.212200   48.7680
# Albuquerque          4.280   595.0000  158.582857  104.5250
# Alexandria          12.420  4164.0500  344.973125   27.0250
# Allen                8.784   244.0060   72.551500   18.7080
# Allentown            3.488   663.0720  121.893143   21.7280
# Altoona              4.419    16.0320   10.225500   10.2255
# Amarillo            19.648  2453.4300  377.306280  142.4224
# Anaheim              3.360  1295.7800  294.765684  119.9600
# Andover             11.210   354.9000  108.962500   34.8700
# Ann Arbor           29.160   619.9500  177.854600   57.9600
# Antioch             19.440    19.4400   19.440000   19.4400
# Apopka               2.952   671.5440  129.222000   27.0180
# Apple Valley         8.640  1194.1650  228.113444   43.1760
# ...

# %%
sales_stats_city2 = superstore.groupby('City')[['Sales', 'Region']].agg([np.min, np.max, np.mean, np.median])

# %%
sales_stats_city2
# Out:
#                      Sales
#                       amin       amax        mean    median
# City
# Aberdeen            25.500    25.5000   25.500000   25.5000
# Abilene              1.392     1.3920    1.392000    1.3920
# Akron                2.286   665.4080  136.212200   48.7680
# Albuquerque          4.280   595.0000  158.582857  104.5250
# Alexandria          12.420  4164.0500  344.973125   27.0250
# Allen                8.784   244.0060   72.551500   18.7080
# Allentown            3.488   663.0720  121.893143   21.7280
# Altoona              4.419    16.0320   10.225500   10.2255
# Amarillo            19.648  2453.4300  377.306280  142.4224
# Anaheim              3.360  1295.7800  294.765684  119.9600
# Andover             11.210   354.9000  108.962500   34.8700
# Ann Arbor           29.160   619.9500  177.854600   57.9600
# Antioch             19.440    19.4400   19.440000   19.4400
# Apopka               2.952   671.5440  129.222000   27.0180
# ...

# %% [markdown]
# # Pivot Table
# Pivot tables are the standard way of aggregating data in spreadsheets.

# %%
piv = superstore.pivot_table(values = 'Sales', index = 'City')

# %%
print(piv)
# Out:
#                         Sales
# City
# Aberdeen            25.500000
# Abilene              1.392000
# Akron              136.212200
# Albuquerque        158.582857
# Alexandria         344.973125
# Allen               72.551500
# Allentown          121.893143
# Altoona             10.225500
# Amarillo           377.306280
# Anaheim            294.765684
# Andover            108.962500
# Ann Arbor          177.854600
# Antioch             19.440000
# Apopka             129.222000
# Apple Valley       228.113444
# Appleton           835.655000
# Arlington          336.908867
# Arlington Heights   14.112000
# Arvada             125.850000
# Asheville          210.768000
# Athens             239.120000
# Atlanta            440.970256
# Atlantic City       23.360000
# Auburn             131.465333
# Aurora             171.418794
# Austin             155.332872
# Avondale           157.801333
# Bakersfield         86.080625
# Baltimore          143.182372
# Bangor             232.890000
# ...

# %%
piv2 = superstore.pivot_table(values = 'Sales', index = "Product_Name", aggfunc=[np.mean, np.median])

# %%
print(piv2)
# Out:
#                                                            mean    median
#                                                           Sales     Sales
# Product_Name
# "While you Were Out" Message Book, One Form per...     8.409333     8.904
# #10 Gummed Flap White Envelopes, 100/Box              10.325000     9.086
# #10 Self-Seal White Envelopes                         27.170500    16.635
# #10 White Business Envelopes,4 1/8 x 9 1/2            63.202333    62.680
# #10- 4 1/8" x 9 1/2" Recycled Envelopes               28.667200    21.850
# #10- 4 1/8" x 9 1/2" Security-Tint Envelopes          18.336000    16.808
# #10-4 1/8" x 9 1/2" Premium Diagonal Seam Envel...    88.144000    88.144
# #6 3/4 Gummed Flap White Envelopes                    17.820000    15.840
# 1.7 Cubic Foot Compact "Cube" Office Refrigerators   451.013333   374.688
# 1/4 Fold Party Design Invitations & White Envel...    24.990000    24.990
# ...

# %%
piv3 = superstore.pivot_table(values = 'Sales', index = "Region", columns='City')

# %%
print(piv3)
# Out:
# City     Aberdeen  Abilene     Akron  Albuquerque  Alexandria    Allen  \
# Region
# Central      25.5    1.392       NaN          NaN         NaN  72.5515
# East          NaN      NaN  136.2122          NaN         NaN      NaN
# South         NaN      NaN       NaN          NaN  344.973125      NaN
# West          NaN      NaN       NaN   158.582857         NaN      NaN
#
# City      Allentown  Altoona   Amarillo     Anaheim    ...      Wilmington  \
# Region                                                 ...
# Central         NaN      NaN  377.30628         NaN    ...             NaN
# East     121.893143  10.2255        NaN         NaN    ...      242.737000
# South           NaN      NaN        NaN         NaN    ...       82.573556
# West            NaN      NaN        NaN  294.765684    ...             NaN
#
# City        Wilson  Woodbury   Woodland  Woodstock  Woonsocket     Yonkers  \
# Region
# Central        NaN    202.55        NaN     285.75         NaN         NaN
# ...

# %%
piv4 = superstore.pivot_table(values = 'Sales', index = "Region", columns='City',fill_value = 0 , margins = True)

# %%
print(piv4)
# Out:
# City     Aberdeen  Abilene     Akron  Albuquerque  Alexandria    Allen  \
# Region
# Central      25.5    1.392    0.0000     0.000000    0.000000  72.5515
# East          0.0    0.000  136.2122     0.000000    0.000000   0.0000
# South         0.0    0.000    0.0000     0.000000  344.973125   0.0000
# West          0.0    0.000    0.0000   158.582857    0.000000   0.0000
# All          25.5    1.392  136.2122   158.582857  344.973125  72.5515
#
# City      Allentown  Altoona   Amarillo     Anaheim     ...         Wilson  \
# Region                                                  ...
# Central    0.000000   0.0000  377.30628    0.000000     ...       0.000000
# East     121.893143  10.2255    0.00000    0.000000     ...       0.000000
# South      0.000000   0.0000    0.00000    0.000000     ...      61.455333
# West       0.000000   0.0000    0.00000  294.765684     ...       0.000000
# All      121.893143  10.2255  377.30628  294.765684     ...      61.455333
#
# ...

# %% [markdown]
# # Data Manipulation With Pandas

# %% [markdown]
# ## Setting and removing indexes

# %% [markdown]
# ### Look at Dataset(superstore)

# %%
print(superstore)
# Out:
#       Row_ID        Order_ID  Order_Date   Ship_Date       Ship+Mode  \
# 0          1  CA-2017-152156   8/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156   8/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688   12/6/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 5          6  CA-2015-115812    9/6/2015  14/06/2015  Standard Class
# 6          7  CA-2015-115812    9/6/2015  14/06/2015  Standard Class
# 7          8  CA-2015-115812    9/6/2015  14/06/2015  Standard Class
# 8          9  CA-2015-115812    9/6/2015  14/06/2015  Standard Class
# 9         10  CA-2015-115812    9/6/2015  14/06/2015  Standard Class
# 10        11  CA-2015-115812    9/6/2015  14/06/2015  Standard Class
# 11        12  CA-2015-115812    9/6/2015  14/06/2015  Standard Class
# 12        13  CA-2018-114412  15/04/2018  20/04/2018  Standard Class
# ...

# %% [markdown]
# ### Set the index of Superstore to "city", assigning to state_id

# %%
state_id = superstore.set_index('City')

# %%
print(state_id)
# Out:
#                  Row_ID        Order_ID  Order_Date   Ship_Date  \
# City
# Henderson             1  CA-2017-152156   8/11/2017  11/11/2017
# Henderson             2  CA-2017-152156   8/11/2017  11/11/2017
# Los Angeles           3  CA-2017-138688   12/6/2017  16/06/2017
# Fort Lauderdale       4  US-2016-108966  11/10/2016  18/10/2016
# Fort Lauderdale       5  US-2016-108966  11/10/2016  18/10/2016
# Los Angeles           6  CA-2015-115812    9/6/2015  14/06/2015
# Los Angeles           7  CA-2015-115812    9/6/2015  14/06/2015
# Los Angeles           8  CA-2015-115812    9/6/2015  14/06/2015
# Los Angeles           9  CA-2015-115812    9/6/2015  14/06/2015
# Los Angeles          10  CA-2015-115812    9/6/2015  14/06/2015
# Los Angeles          11  CA-2015-115812    9/6/2015  14/06/2015
# Los Angeles          12  CA-2015-115812    9/6/2015  14/06/2015
# Concord              13  CA-2018-114412  15/04/2018  20/04/2018
# Seattle              14  CA-2017-161389   5/12/2017  10/12/2017
# ...

# %% [markdown]
# ## Reset the index, keeping its contents

# %%
print(superstore.reset_index())
# Out:
#       index  Row_ID        Order_ID  Order_Date   Ship_Date       Ship+Mode  \
# 0         0       1  CA-2017-152156   8/11/2017  11/11/2017    Second Class
# 1         1       2  CA-2017-152156   8/11/2017  11/11/2017    Second Class
# 2         2       3  CA-2017-138688   12/6/2017  16/06/2017    Second Class
# 3         3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4         4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 5         5       6  CA-2015-115812    9/6/2015  14/06/2015  Standard Class
# 6         6       7  CA-2015-115812    9/6/2015  14/06/2015  Standard Class
# 7         7       8  CA-2015-115812    9/6/2015  14/06/2015  Standard Class
# 8         8       9  CA-2015-115812    9/6/2015  14/06/2015  Standard Class
# 9         9      10  CA-2015-115812    9/6/2015  14/06/2015  Standard Class
# 10       10      11  CA-2015-115812    9/6/2015  14/06/2015  Standard Class
# ...

# %% [markdown]
# ### # Reset the index, dropping its contents

# %%
print(superstore.reset_index(drop=True))
# Out:
#       Row_ID        Order_ID  Order_Date   Ship_Date       Ship+Mode  \
# 0          1  CA-2017-152156   8/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156   8/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688   12/6/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 5          6  CA-2015-115812    9/6/2015  14/06/2015  Standard Class
# 6          7  CA-2015-115812    9/6/2015  14/06/2015  Standard Class
# 7          8  CA-2015-115812    9/6/2015  14/06/2015  Standard Class
# 8          9  CA-2015-115812    9/6/2015  14/06/2015  Standard Class
# 9         10  CA-2015-115812    9/6/2015  14/06/2015  Standard Class
# 10        11  CA-2015-115812    9/6/2015  14/06/2015  Standard Class
# 11        12  CA-2015-115812    9/6/2015  14/06/2015  Standard Class
# 12        13  CA-2018-114412  15/04/2018  20/04/2018  Standard Class
# ...

# %% [markdown]
# # Subsetting with .loc[]
# .loc[]: a subsetting method that accepts index values. When you pass it a single argument, it will take a subset of rows.

# %% [markdown]
# ### Create a list called cities that contains "MoscHendersonow" and "Orem".

# %%
cities = ['Aberdeen', 'Orem']

# %%
print(superstore[superstore['City'].isin(cities)])
# Out:
#       Row_ID        Order_ID  Order_Date   Ship_Date       Ship+Mode  \
# 24        25  CA-2016-106320  25/09/2016  30/09/2016  Standard Class
# 718      719  CA-2015-104472    2/6/2015    7/6/2015  Standard Class
# 719      720  CA-2015-104472    2/6/2015    7/6/2015  Standard Class
# 2558    2559  CA-2016-147788  31/05/2016    4/6/2016  Standard Class
# 2559    2560  CA-2016-147788  31/05/2016    4/6/2016  Standard Class
# 2560    2561  CA-2016-147788  31/05/2016    4/6/2016  Standard Class
# 7707    7708  CA-2018-100237  15/10/2018  19/10/2018  Standard Class
# 8796    8797  CA-2017-106397    7/7/2017  13/07/2017  Standard Class
# 8797    8798  CA-2017-106397    7/7/2017  13/07/2017  Standard Class
# 9260    9261  CA-2018-167976  11/11/2018  14/11/2018    Second Class
#
#      Customer_ID       Customer_Name      Segment        Country      City  \
# 24      EB-13870         Emily Burns     Consumer  United States      Orem
# ...

# %% [markdown]
# # Setting multi-level indexes

# %% [markdown]
# ###  Index  by country & city

# %%
superstore_ind = superstore.set_index(['Country', 'City'])

# %% [markdown]
# ## Specify two country/city pairs

# %%
rows_to_keep = [("United States", "Henderson"),('United States', "Franklin")]

# %% [markdown]
# ### Print and subset Superstore for rows_to_keep using .loc[].

# %%
print(superstore_ind.loc[rows_to_keep])
# Out:
#                          Row_ID        Order_ID  Order_Date   Ship_Date  \
# Country       City
# United States Henderson       1  CA-2017-152156   8/11/2017  11/11/2017
#               Henderson       2  CA-2017-152156   8/11/2017  11/11/2017
#               Henderson     539  CA-2016-134894   7/12/2016  11/12/2016
#               Henderson     540  CA-2016-134894   7/12/2016  11/12/2016
#               Henderson     997  CA-2016-162537  28/10/2016   3/11/2016
#               Henderson     998  CA-2016-162537  28/10/2016   3/11/2016
#               Henderson     999  CA-2016-162537  28/10/2016   3/11/2016
#               Henderson    1000  CA-2016-162537  28/10/2016   3/11/2016
#               Henderson    1867  CA-2018-118857  15/04/2018  18/04/2018
#               Henderson    2322  CA-2016-109470  31/12/2016    3/1/2017
#               Henderson    2323  CA-2016-109470  31/12/2016    3/1/2017
#               Henderson    2324  CA-2016-109470  31/12/2016    3/1/2017
# ...

# %% [markdown]
# # Sorting by index values

# %% [markdown]
# ### Sort superstore_ind by the index values.

# %%
print(superstore_ind.sort_index())
# Out:
#                            Row_ID        Order_ID  Order_Date   Ship_Date  \
# Country       City
# United States Aberdeen       9261  CA-2018-167976  11/11/2018  14/11/2018
#               Abilene        6990  CA-2018-165099  11/12/2018  13/12/2018
#               Akron           201  CA-2018-105074  24/06/2018  29/06/2018
#               Akron           454  CA-2018-147277  20/10/2018  24/10/2018
#               Akron           455  CA-2018-147277  20/10/2018  24/10/2018
#               Akron          3201  CA-2015-164224  18/05/2015  20/05/2015
#               Akron          3202  CA-2015-164224  18/05/2015  20/05/2015
#               Akron          3561  CA-2018-109757    4/9/2018    9/9/2018
#               Akron          3562  CA-2018-109757    4/9/2018    9/9/2018
#               Akron          3563  CA-2018-109757    4/9/2018    9/9/2018
#               Akron          3564  CA-2018-109757    4/9/2018    9/9/2018
# ...

# %% [markdown]
# ### Sort by index values at the city level

# %%
print(superstore_ind.sort_index(level='City'))
# Out:
#                            Row_ID        Order_ID  Order_Date   Ship_Date  \
# Country       City
# United States Aberdeen       9261  CA-2018-167976  11/11/2018  14/11/2018
#               Abilene        6990  CA-2018-165099  11/12/2018  13/12/2018
#               Akron           201  CA-2018-105074  24/06/2018  29/06/2018
#               Akron           454  CA-2018-147277  20/10/2018  24/10/2018
#               Akron           455  CA-2018-147277  20/10/2018  24/10/2018
#               Akron          3201  CA-2015-164224  18/05/2015  20/05/2015
#               Akron          3202  CA-2015-164224  18/05/2015  20/05/2015
#               Akron          3561  CA-2018-109757    4/9/2018    9/9/2018
#               Akron          3562  CA-2018-109757    4/9/2018    9/9/2018
#               Akron          3563  CA-2018-109757    4/9/2018    9/9/2018
#               Akron          3564  CA-2018-109757    4/9/2018    9/9/2018
# ...

# %% [markdown]
# ### Sort  by ascending country then descending city.

# %%
print(superstore_ind.sort_index(level=['Country', 'City'], ascending=(True, False)))
# Out:
#                            Row_ID        Order_ID  Order_Date   Ship_Date  \
# Country       City
# United States Aberdeen       9261  CA-2018-167976  11/11/2018  14/11/2018
#               Abilene        6990  CA-2018-165099  11/12/2018  13/12/2018
#               Akron           201  CA-2018-105074  24/06/2018  29/06/2018
#               Akron           454  CA-2018-147277  20/10/2018  24/10/2018
#               Akron           455  CA-2018-147277  20/10/2018  24/10/2018
#               Akron          3201  CA-2015-164224  18/05/2015  20/05/2015
#               Akron          3202  CA-2015-164224  18/05/2015  20/05/2015
#               Akron          3561  CA-2018-109757    4/9/2018    9/9/2018
#               Akron          3562  CA-2018-109757    4/9/2018    9/9/2018
#               Akron          3563  CA-2018-109757    4/9/2018    9/9/2018
#               Akron          3564  CA-2018-109757    4/9/2018    9/9/2018
# ...

# %% [markdown]
# # Day-13 Slicing and subsetting with .loc and .iloc

# %% [markdown]
# ### Slicing index values

# %% [markdown]
# ### Sort the index of superstore_ind

# %%
superstore_srt = superstore_ind.sort_index()

# %%
country_city
# Out:
#       Row_ID        Order_ID  Order_Date   Ship_Date       Ship+Mode  \
# 0          1  CA-2017-152156   8/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688   12/6/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 12        13  CA-2018-114412  15/04/2018  20/04/2018  Standard Class
# 13        14  CA-2017-161389   5/12/2017  10/12/2017  Standard Class
# 14        15  US-2016-118983  22/11/2016  26/11/2016  Standard Class
# 16        17  CA-2015-105893  11/11/2015  18/11/2015  Standard Class
# 17        18  CA-2015-167164  13/05/2015  15/05/2015    Second Class
# 18        19  CA-2015-143336  27/08/2015    1/9/2015    Second Class
# 21        22  CA-2017-137330   9/12/2017  13/12/2017  Standard Class
# 23        24  US-2018-156909  16/07/2018  18/07/2018    Second Class
# 24        25  CA-2016-106320  25/09/2016  30/09/2016  Standard Class
# 34        35  CA-2018-107727  19/10/2018  23/10/2018    Second Class
# ...

# %% [markdown]
# ## Subset rows from Product_Id , Category

# %%
print(superstore_srt.loc['Memphis':'Kissimmee'])

print(superstore_srt.loc["California":"Georgia"])

print(superstore_srt.loc[("United States", "California"):("United States", "Memphis")])
# Out:
# Empty DataFrame
# Columns: [Row_ID, Order_ID, Order_Date, Ship_Date, Ship+Mode, Customer_ID, Customer_Name, Segment, State, Postal_Code, Region, Product_ID, Category, Sub_Category, Product_Name, Sales]
# Index: []
# Empty DataFrame
# Columns: [Row_ID, Order_ID, Order_Date, Ship_Date, Ship+Mode, Customer_ID, Customer_Name, Segment, State, Postal_Code, Region, Product_ID, Category, Sub_Category, Product_Name, Sales]
# Index: []
#                             Row_ID        Order_ID  Order_Date   Ship_Date  \
# Country       City
# United States Camarillo       7214  CA-2018-154949  15/10/2018  19/10/2018
#               Camarillo       7404  CA-2016-100146  14/05/2016  19/05/2016
#               Camarillo       7405  CA-2016-100146  14/05/2016  19/05/2016
#               Camarillo       7406  CA-2016-100146  14/05/2016  19/05/2016
#               Camarillo       7407  CA-2016-100146  14/05/2016  19/05/2016
#               Cambridge       6268  CA-2016-115392   1/10/2016   4/10/2016
# ...

# %% [markdown]
# # Slicing time series
# Slicing is particularly useful for time series since it's a common thing to want to filter for data within a date range. Add the date column to the index, then use .loc[] to perform the subsetting. The important thing to remember is to keep your dates in ISO 8601 format, that is, yyyy-mm-dd.

# %%
superstore_bool = superstore[(superstore['Order_Date'] >= '2015-01-01') & (superstore['Order_Date']<= '2018-0101')]

# %%
# Set date as an index and sort the index

superstore_ind =  superstore.set_index('Order_Date').sort_index()

# %%
# # Use .loc[] to subset superstore_ind for rows in 2015 and 2018

print(superstore_ind.loc['2015':'2018'])
# Out:
# Empty DataFrame
# Columns: [Row_ID, Order_ID, Ship_Date, Ship+Mode, Customer_ID, Customer_Name, Segment, Country, City, State, Postal_Code, Region, Product_ID, Category, Sub_Category, Product_Name, Sales]
# Index: []

# %%
# Use .loc[] to subset  for rows from Aug 2015 to Feb 2018
print(superstore_ind.loc['2015-08-01':'2018-02-01'])
# Out:
# Empty DataFrame
# Columns: [Row_ID, Order_ID, Ship_Date, Ship+Mode, Customer_ID, Customer_Name, Segment, Country, City, State, Postal_Code, Region, Product_ID, Category, Sub_Category, Product_Name, Sales]
# Index: []

# %% [markdown]
# # Subsetting by row/column number

# %% [markdown]
# ### Get 23rd row, 2nd column (index 22, 1)

# %%
print(superstore.loc[1:2])
# Out:
#    Row_ID        Order_ID Order_Date   Ship_Date     Ship+Mode Customer_ID  \
# 1       2  CA-2017-152156  8/11/2017  11/11/2017  Second Class    CG-12520
# 2       3  CA-2017-138688  12/6/2017  16/06/2017  Second Class    DV-13045
#
#      Customer_Name    Segment        Country         City       State  \
# 1      Claire Gute   Consumer  United States    Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  California
#
#    Postal_Code Region       Product_ID         Category Sub_Category  \
# 1      42420.0  South  FUR-CH-10000454        Furniture       Chairs
# 2      90036.0   West  OFF-LA-10000240  Office Supplies       Labels
#
#                                         Product_Name   Sales
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94
# 2  Self-Adhesive Address Labels for Typewriters b...   14.62

# %%
# Use slicing to get the first 5 rows
print(superstore.iloc[:5])
# Out:
#    Row_ID        Order_ID  Order_Date   Ship_Date       Ship+Mode Customer_ID  \
# 0       1  CA-2017-152156   8/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156   8/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688   12/6/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
# Use slicing to get columns 3 to 4
print(superstore.iloc[:, 2:4])
# Out:
#       Order_Date   Ship_Date
# 0      8/11/2017  11/11/2017
# 1      8/11/2017  11/11/2017
# 2      12/6/2017  16/06/2017
# 3     11/10/2016  18/10/2016
# 4     11/10/2016  18/10/2016
# 5       9/6/2015  14/06/2015
# 6       9/6/2015  14/06/2015
# 7       9/6/2015  14/06/2015
# 8       9/6/2015  14/06/2015
# 9       9/6/2015  14/06/2015
# 10      9/6/2015  14/06/2015
# 11      9/6/2015  14/06/2015
# 12    15/04/2018  20/04/2018
# 13     5/12/2017  10/12/2017
# 14    22/11/2016  26/11/2016
# 15    22/11/2016  26/11/2016
# 16    11/11/2015  18/11/2015
# 17    13/05/2015  15/05/2015
# 18    27/08/2015    1/9/2015
# 19    27/08/2015    1/9/2015
# 20    27/08/2015    1/9/2015
# 21     9/12/2017  13/12/2017
# 22     9/12/2017  13/12/2017
# 23    16/07/2018  18/07/2018
# 24    25/09/2016  30/09/2016
# 25    16/01/2017  20/01/2017
# 26    16/01/2017  20/01/2017
# 27    17/09/2016  21/09/2016
# 28    17/09/2016  21/09/2016
# 29    17/09/2016  21/09/2016
# ...          ...         ...
# ...

# %%
# Use slicing in both directions at once
print(superstore.iloc[:5, 2:4])
# Out:
#    Order_Date   Ship_Date
# 0   8/11/2017  11/11/2017
# 1   8/11/2017  11/11/2017
# 2   12/6/2017  16/06/2017
# 3  11/10/2016  18/10/2016
# 4  11/10/2016  18/10/2016
