# %% [markdown]
# # Visualizing Your Pandas DataFrame

# %%
# %matplotlib inline

# %%
import pandas as pd

# %%
nba = pd.read_csv("Desktop/nba_all_elo.csv")

# %%
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...   win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...   40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...   41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...   42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...   40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...   38.864048     WSC  Capitols       50
#
# ...

# %% [markdown]
# Both Series and DataFrame objects have a .plot() method, which is a wrapper around matplotlib.pyplot.plot(). By default, it creates a line plot. Visualize how many points the Knicks scored throughout the seasons:

# %%
nba[nba["fran_id"] == "Knicks"].groupby("year_id")["pts"].sum().plot()

# %% [markdown]
# This shows a line plot with several peaks and two notable valleys around the years 2000 and 2010:

# %%
nba[nba['game_location']=='H'].groupby('game_result').sum().plot()
# Out:
# C:\Users\ANUSHA\Anaconda3\lib\site-packages\matplotlib\legend.py:592: UserWarning: The handle <matplotlib.lines.Line2D object at 0x000001454E97FCF8> has a label of '_iscopy' which cannot be automatically added to the legend.
#   'legend.'.format(handle, label))

# %%
nba[nba["fran_id"] == "Stags"].groupby("year_id")["pts"].sum().plot()

# %%
nba[nba["fran_id"] == "Falcons"].groupby("year_id")["pts"].sum().plot()

# %%
nba[nba["fran_id"] == "Huskies"].groupby("year_id")["pts"].sum().plot()

# %%
nba[nba["opp_id"] == "CHS"].groupby("year_id")["pts"].sum().plot()

# %%
nba[nba["opp_id"] == "CHS"].groupby("game_location")["pts"].sum().plot()

# %% [markdown]
# # Bar plot

# %%
nba["fran_id"].value_counts().head(10).plot(kind="bar")

# %%
nba["year_id"].value_counts().head(10).plot(kind="bar")

# %%
nba["opp_id"].value_counts().head(10).plot(kind="bar")

# %%
nba["game_location"].value_counts().head(10).plot(kind="bar")

# %%
nba["is_playoffs"].value_counts().head(10).plot(kind="bar")

# %% [markdown]
# # Conclusion
# Here is end of my pandas practice, I have learned how to start exploring a dataset with the Pandas Python library. Saw how to access specific rows and columns to tame even the largest of datasets. Speaking of taming, I’ve also seen multiple techniques to prepare and clean your data, by specifying the data type of columns, dealing with missing values, and more. I’ve even created queries, aggregations, and plots based on those.
